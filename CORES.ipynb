# %% [markdown]
# <a href="https://colab.research.google.com/github/MagnoSales/Colors-in-Notebook/blob/main/CORES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Como colorir prints e resultados no notebbok

# %%
pip install nbconvert nbformat

# %%
# cores
# https://www.kaggle.com/discussions/general/273188

PRETO = '\033[30m'
VERMELHO_BOLD = '\033[1;31;43m'
VERMELHO = '\033[43m'
VERDE = '\033[32m'
AMARELO = '\033[33m'
AZUL = '\033[34m'
MAGENTA = '\033[35m'
CIANO = '\033[36m'
BRANCO = '\033[37m'
RESET = '\033[0m' # Reseta a cor para o padrão

# %%
print("\033[0;37;40m Normal text\n")
print("\033[2;37;40m Underlined text\033[0;37;40m \n")
print("\033[1;37;40m Bright Colour\033[0;37;40m \n")
print("\033[3;37;40m Negative Colour\033[0;37;40m \n")
print("\033[5;37;40m Negative Colour\033[0;37;40m\n")
print("\033[1;37;40m \033[2;37:40m TextColour BlackBackground TextColour GreyBackground WhiteText ColouredBackground\033[0;37;40m\n")
print("\033[1;30;40m Dark Gray \033[0m 1;30;40m \033[0;30;47m Black \033[0m 0;30;47m \033[0;37;41m Black \033[0m 0;37;41m")
print("\033[1;31;40m Bright Red \033[0m 1;31;40m \033[0;31;47m Red \033[0m 0;31;47m \033[0;37;42m Black \033[0m 0;37;42m")
print("\033[1;32;40m Bright Green \033[0m 1;32;40m \033[0;32;47m Green \033[0m 0;32;47m \033[0;37;43m Black \033[0m 0;37;43m")
print("\033[1;33;40m Yellow \033[0m 1;33;40m \033[0;33;47m Brown \033[0m 0;33;47m \033[0;37;44m Black \033[0m 0;37;44m")
print("\033[1;34;40m Bright Blue \033[0m 1;34;40m \033[0;34;47m Blue \033[0m 0;34;47m \033[0;37;45m Black \033[0m 0;37;45m")
print("\033[1;35;40m Bright Magenta \033[0m 1;35;40m \033[0;35;47m Magenta \033[0m 0;35;47m \033[0;37;46m Black \033[0m 0;37;46m")
print("\033[1;36;40m Bright Cyan \033[0m 1;36;40m \033[0;36;47m Cyan \033[0m 0;36;47m \033[0;37;47m Black \033[0m 0;37;47m")
print("\033[1;37;40m White \033[0m 1;37;40m \033[0;37;40m Light Grey \033[0m 0;37;40m \033[0;37;48m Black \033[0m 0;37;48m")
# Out:
#  Normal text
#
#  Underlined text
#
#  Bright Colour
#
#  Negative Colour
#
#  Negative Colour
#
#  [2;37:40m TextColour BlackBackground TextColour GreyBackground WhiteText ColouredBackground
#
#  Dark Gray  1;30;40m  Black  0;30;47m  Black  0;37;41m
#  Bright Red  1;31;40m  Red  0;31;47m  Black  0;37;42m
#  Bright Green  1;32;40m  Green  0;32;47m  Black  0;37;43m
#  Yellow  1;33;40m  Brown  0;33;47m  Black  0;37;44m
#  Bright Blue  1;34;40m  Blue  0;34;47m  Black  0;37;45m
#  Bright Magenta  1;35;40m  Magenta  0;35;47m  Black  0;37;46m
#  Bright Cyan  1;36;40m  Cyan  0;36;47m  Black  0;37;47m
#  White  1;37;40m  Light Grey  0;37;40m  Black  0;37;48m

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
   print(VERMELHO_BOLD + "....ATENÇÃO...." + RESET)
   print(VERDE + 'Sem NF para eu aprovar'+ RESET)
# Out:
# ....ATENÇÃO....
# Sem NF para eu aprovar

# %%
print("\033[0;37;40m Normal text\n")
print("\033[2;37;40m Underlined text\033[0;37;40m \n")
print("\033[1;37;40m Bright Colour\033[0;37;40m \n")
print("\033[3;37;40m Negative Colour\033[0;37;40m \n")
print("\033[5;37;40m Negative Colour\033[0;37;40m\n")
print("\033[1;37;40m \033[2;37:40m \nTextColour BlackBackground         TextColour GreyBackground      WhiteText ColouredBackground\033[0;37;40m\n")

# Usando f-strings com largura fixa para alinhar as colunas
print(f"\033[1;30;40m{'Dark Gray':<20}\033[0m 1;30;40m      \033[0;30;47m{'Black':<15}\033[0m 0;30;47m      \033[0;37;41m{'Black':<15}\033[0m 0;37;41m") #Adicionei 5 espaços após  ;40m e ;47m
print(f"\033[1;31;40m{'Bright Red':<20}\033[0m 1;31;40m      \033[0;31;47m{'Red':<15}\033[0m 0;31;47m      \033[0;37;42m{'Black':<15}\033[0m 0;37;42m")
print(f"\033[1;32;40m{'Bright Green':<20}\033[0m 1;32;40m      \033[0;32;47m{'Green':<15}\033[0m 0;32;47m      \033[0;37;43m{'Black':<15}\033[0m 0;37;43m")
print(f"\033[1;33;40m{'Yellow':<20}\033[0m 1;33;40m      \033[0;33;47m{'Brown':<15}\033[0m 0;33;47m      \033[0;37;44m{'Black':<15}\033[0m 0;37;44m")
print(f"\033[1;34;40m{'Bright Blue':<20}\033[0m 1;34;40m      \033[0;34;47m{'Blue':<15}\033[0m 0;34;47m      \033[0;37;45m{'Black':<15}\033[0m 0;37;45m")
print(f"\033[1;35;40m{'Bright Magenta':<20}\033[0m 1;35;40m      \033[0;35;47m{'Magenta':<15}\033[0m 0;35;47m      \033[0;37;46m{'Black':<15}\033[0m 0;37;46m")
print(f"\033[1;36;40m{'Bright Cyan':<20}\033[0m 1;36;40m      \033[0;36;47m{'Cyan':<15}\033[0m 0;36;47m      \033[0;37;47m{'Black':<15}\033[0m 0;37;47m")
print(f"\033[1;37;40m{'White':<20}\033[0m 1;37;40m      \033[0;37;40m{'Light Grey':<15}\033[0m 0;37;40m      \033[0;37;48m{'Black':<15}\033[0m 0;37;48m")
# Out:
#  Normal text
#
#  Underlined text
#
#  Bright Colour
#
#  Negative Colour
#
#  Negative Colour
#
#  [2;37:40m
# TextColour BlackBackground         TextColour GreyBackground      WhiteText ColouredBackground
#
# Dark Gray            1;30;40m      Black           0;30;47m      Black           0;37;41m
# Bright Red           1;31;40m      Red             0;31;47m      Black           0;37;42m
# Bright Green         1;32;40m      Green           0;32;47m      Black           0;37;43m
# Yellow               1;33;40m      Brown           0;33;47m      Black           0;37;44m
# Bright Blue          1;34;40m      Blue            0;34;47m      Black           0;37;45m
# Bright Magenta       1;35;40m      Magenta         0;35;47m      Black           0;37;46m
# Bright Cyan          1;36;40m      Cyan            0;36;47m      Black           0;37;47m
# White                1;37;40m      Light Grey      0;37;40m      Black           0;37;48m

# %% [markdown]
# O que mudou:
#
# Usei f-strings com {texto:<largura} para garantir que cada coluna tenha largura fixa
# Primeira coluna: {texto:<20} = 20 caracteres
# Segunda e terceira colunas: {texto:<15} = 15 caracteres cada
# O < alinha o texto à esquerda e preenche com espaços à direita
#
# Agora as colunas ficarão perfeitamente alinhadas como na primeira imagem! 🎯

# %%
print("\033[0;37;40m Normal text\n")
print("\033[2;37;40m Underlined text\033[0;37;40m \n")
print("\033[1;37;40m Bright Colour\033[0;37;40m \n")
print("\033[3;37;40m Negative Colour\033[0;37;40m \n")
print("\033[5;37;40m Negative Colour\033[0;37;40m\n")
print("\033[1;37;40m \033[2;37:40m TextColour BlackBackground TextColour GreyBackground WhiteText ColouredBackground\033[0;37;40m\n")

# Usando f-strings com largura fixa para alinhar as colunas
print(f"\033[1;30;40m{'Dark Gray':<30}\033[0m 1;30;40m \033[0;30;47m{'Black':<20}\033[0m 0;30;47m \033[0;37;41m{'Black':<20}\033[0m 0;37;41m")
print(f"\033[1;31;40m{'Bright Red':<30}\033[0m 1;31;40m \033[0;31;47m{'Red':<20}\033[0m 0;31;47m \033[0;37;42m{'Black':<20}\033[0m 0;37;42m")
print(f"\033[1;32;40m{'Bright Green':<30}\033[0m 1;32;40m \033[0;32;47m{'Green':<20}\033[0m 0;32;47m \033[0;37;43m{'Black':<20}\033[0m 0;37;43m")
print(f"\033[1;33;40m{'Yellow':<30}\033[0m 1;33;40m \033[0;33;47m{'Brown':<20}\033[0m 0;33;47m \033[0;37;44m{'Black':<20}\033[0m 0;37;44m")
print(f"\033[1;34;40m{'Bright Blue':<30}\033[0m 1;34;40m \033[0;34;47m{'Blue':<20}\033[0m 0;34;47m \033[0;37;45m{'Black':<20}\033[0m 0;37;45m")
print(f"\033[1;35;40m{'Bright Magenta':<30}\033[0m 1;35;40m \033[0;35;47m{'Magenta':<20}\033[0m 0;35;47m \033[0;37;46m{'Black':<20}\033[0m 0;37;46m")
print(f"\033[1;36;40m{'Bright Cyan':<30}\033[0m 1;36;40m \033[0;36;47m{'Cyan':<20}\033[0m 0;36;47m \033[0;37;47m{'Black':<20}\033[0m 0;37;47m")
print(f"\033[1;37;40m{'White':<30}\033[0m 1;37;40m \033[0;37;40m{'Light Grey':<20}\033[0m 0;37;40m \033[0;37;48m{'Black':<20}\033[0m 0;37;48m")
# Out:
#  Normal text
#
#  Underlined text
#
#  Bright Colour
#
#  Negative Colour
#
#  Negative Colour
#
#  [2;37:40m TextColour BlackBackground TextColour GreyBackground WhiteText ColouredBackground
#
# Dark Gray                      1;30;40m Black                0;30;47m Black                0;37;41m
# Bright Red                     1;31;40m Red                  0;31;47m Black                0;37;42m
# Bright Green                   1;32;40m Green                0;32;47m Black                0;37;43m
# Yellow                         1;33;40m Brown                0;33;47m Black                0;37;44m
# Bright Blue                    1;34;40m Blue                 0;34;47m Black                0;37;45m
# Bright Magenta                 1;35;40m Magenta              0;35;47m Black                0;37;46m
# Bright Cyan                    1;36;40m Cyan                 0;36;47m Black                0;37;47m
# ...
